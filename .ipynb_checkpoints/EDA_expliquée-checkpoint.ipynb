# %% [markdown]
# # L'IA au service des agents immobiliers - Silicon Valley

# %% [markdown]
# **On importe les librairies**
# import pandas as pd
# import numpy as np
#
# **Librairies pour visualisation**
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# import sklearn
# **classe pour l'ACP**
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import scale
# from sklearn import decomposition
# from sklearn import preprocessing
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Lecture du fichier CSV**
#
# californie = pd.read_csv('housing_test_data01.csv')

# %% [markdown]
# ### Partie Data Cleaning

# %% [markdown]
# Nous allons étudier le dataset, retirer les NaN, et gérer les valeurs abhérantes s'il y en a.

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# 10 colonnes: 9 numérique 1 catégorielle ,
# Target numérique: median_house_value,
# 16512 lignes,
# Présence de NaN dans une colonne : Total_bedroom

# %% [markdown]
# On retire la colonne 'Unnamed 0' qui ne sert pas pour notre cas. Ensuite, j'ai vérifié s'il n'y avait pas de valeurs null dans notre target 'median_house_value'

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# J'ai transformé mes variables de 'ocean_proximity' en float pour pouvoir les lires dans la partie visualisation, afin de voir et expliquer les différentes corrélations.

# %% [markdown]
# Ensuite j'ai compter tous les nulls.
# Ils sont tous dans la colonne 'total_bedrooms'.
# J'utilise la méthode .fillna afin de les supprimer toutes.

# %% [markdown]
# ![Screenshot_4.png](attachment:Screenshot_4.png)

# %% [markdown]
# J'ai en parallèle créé un second DataFrame nettoyé de la même manière pour lui appliquer un get_dummies.
# get_dummies fait la même chose que One Hot Encoder, permettant de passer nos variables de 'ocean_proximity' en colonne. Ceci permettra au modèle de ne pas mettre trop de poids à ces données, puisqu'elles ne seront plus associés à des chiffres.

# %% [markdown]
# ![Screenshot_5.png](attachment:Screenshot_5.png)

# %% [markdown]
# ### Partie visualisation des données

# %% [markdown]
# J'ai réalisé de nombreux plot et j'ai tenté d'expliquer ce qu'il se passe avec les données.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement.png](attachment:t%C3%A9l%C3%A9chargement.png)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%281%29.png](attachment:t%C3%A9l%C3%A9chargement%20%281%29.png)

# %% [markdown]
# Comme le montrent les deux graphiques ci-dessus :
# total_bedrooms est corrélé avec total_rooms
# population avec households mais ils sont tous les deux corrélés avec total_bedrooms ainsi qu'avec total_rooms longitude et latitude sont liés (donc corrélés entre eux d'une autre manière)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%282%29.png](attachment:t%C3%A9l%C3%A9chargement%20%282%29.png)

# %% [markdown]
# On retrouve un nombre important de maisons proche de l'océan.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%283%29.png](attachment:t%C3%A9l%C3%A9chargement%20%283%29.png)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%284%29.png](attachment:t%C3%A9l%C3%A9chargement%20%284%29.png)

# %% [markdown]
# La valeur est plus élevé pour les maisons qui sont à moins d'une heure de l'océan (<1H OCEAN), ainsi que celles qui sont à l'intérieur de l'île (INLAND)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%285%29.png](attachment:t%C3%A9l%C3%A9chargement%20%285%29.png)

# %% [markdown]
# On trouve des maisons avec plus de pièces (donc potentiellement plus grandes) proches des côtes.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%286%29.png](attachment:t%C3%A9l%C3%A9chargement%20%286%29.png)

# %% [markdown]
# Revenu médian de la population, avec une majorité ayant un revenu moyen entre 5000 et 12000$.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%287%29.png](attachment:t%C3%A9l%C3%A9chargement%20%287%29.png)

# %% [markdown]
# Une bonne partie de la population se trouve proche de l'océan.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%288%29.png](attachment:t%C3%A9l%C3%A9chargement%20%288%29.png)

# %% [markdown]
# La Californie (par emplacement des maisons avec la valeur 'ocean_proximity')

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%289%29.png](attachment:t%C3%A9l%C3%A9chargement%20%289%29.png)

# %% [markdown]
# La Californie par rapport au prix des maisons (avec la valeur 'median_house_value')
# Les maisons plus proches de l'océan sont bien plus chères que celles à l'intérieur des terres.

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%2810%29.png](attachment:t%C3%A9l%C3%A9chargement%20%2810%29.png)

# %% [markdown]
# Population sur la Californie

# %% [markdown]
# ### Partie PCA

# %% [markdown]
# Après le nettoyage des données, je les prépare pour créé mon modèle en appliquant un to_csv pour avoir ce nouveau dataset clean.
# En parallèle, j'ai préparé le second dataset (qui a eu le get_dummies), puis un troisième (sans le get_dummies mais avec la méthode mapping) en appliquant les méthodes Scale et PCA pour réduire les données.

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement.png](attachment:t%C3%A9l%C3%A9chargement.png)

# %% [markdown]
# ![t%C3%A9l%C3%A9chargement%20%281%29.png](attachment:t%C3%A9l%C3%A9chargement%20%281%29.png)

# %% [markdown]
# Après l'étude de la valeur expliquée avec ce coude, on peut se rendre compte du seuil à fixer, qui est à 0.90 (représentant 90% de données expliquées) ce qui correspond à 4 composants.
# Je refais donc une PCA avec le bon paramètre.

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# J'ai effectué le même processus sur le second dataset qui a reçu un get_dummies.
# J'ai dû retirer la target 'ocean_proximity' car il ne pouvait pas le prendre en compte.

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# ![Screenshot_4.png](attachment:Screenshot_4.png)

# %% [markdown]
# Mes datasets sont prêts !

# %% [markdown]
# J'utilise la commande to_csv pour créer quatre jeux de données :
# **df_californie**  (dataset classique)
# **df_data_californie** (dataset classique avec dummies)
# **californie_df_pca**  (le dataset classique avec pca)
# **californie_dummies_pca** (le dataset avec dummies et pca)

# %% [markdown]
# ## Partie ML

# %% [markdown]
# Premier test d'un model avec la méthode LinearRegression sur les données nettoyées dans le dataset 'df_californie'.

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# Le score est de 0.61. Il est au dessus de la moyenne mais n'est pas un score extraordinaire.

# %% [markdown]
# J'ai tenté d'améliorer le modèle en lui donnant le jeu de données 'df_pca' , avec la PCA de 4 + la target.

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# Le score est de 0.87, ce qui est plutôt bon !

# %% [markdown]
# Le troisième modèle testé a travaillé sur le jeu de donnée avec une PCA de 3.

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# Le score est de 0.85, moins bon que celui avec la PCA de 4 mais pas si mal aussi !

# %% [markdown]
# ## Test du model sur un dataset Standardisé

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# J'ai tenté la méthode Standarscaler sur le premier Dataset pour tester le modèle sur ces données standardisées.

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# Il sort un score de 0.61 ce qui reste toujours moins bien que les précédentes sorties de LinearRegression avec des données PCA.

# %% [markdown]
# ## Test du model sur un dataset Normalisé

# %% [markdown]
# J'ai refait la même procédure mais en normalisant les données.

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# Le score n'est pas meilleur que la standardisation et toujours en dessous de la PCA.
